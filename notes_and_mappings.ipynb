# %% [markdown]
# # CHPL Newsdex
#
# TODO: write / cleanup this info
#
# As of Jan 2023 the Newsdex site runs on a Millennium system and is referred to as a "Reference Database" and contains approximatly 1.8 Million records. The records are typically short, and only contain a handful of bibliograhic record fields.
#
# ## Newsdex usage stats—Google Analytics
#
# ### Week of Jan 16-21 2023
# <img src="MicrosoftTeams-image (36).png"></img>
#
# ### Last year (as of Jan 27, 2023)
# <img src="MicrosoftTeams-image (37).png"></img>

# %% [markdown]
# ## Newsdex Record Stats
#
# ---
#
# ### by record cat_date
#
# | strftime('%Y', record.cat_date) | count(\*) |
# | ------------------------------- | --------- |
# |                                 | 678       |
# | 1992                            | 480       |
# | 1993                            | 3158      |
# | 1994                            | 3239      |
# | 1995                            | 3935      |
# | 1996                            | 3892      |
# | 1997                            | 2868      |
# | 1998                            | 1934      |
# | 1999                            | 2525      |
# | 2000                            | 3401      |
# | 2001                            | 3444      |
# | 2002                            | 2546      |
# | 2003                            | 1865      |
# | 2004                            | 1552171   |
# | 2005                            | 26201     |
# | 2006                            | 25627     |
# | 2007                            | 18642     |
# | 2008                            | 11844     |
# | 2009                            | 30446     |
# | 2010                            | 30629     |
# | 2011                            | 27862     |
# | 2012                            | 34339     |
# | 2013                            | 25060     |
# | 2014                            | 19446     |
# | 2015                            | 16770     |
# | 2016                            | 15807     |
# | 2017                            | 11508     |
# | 2018                            | 4483      |
# | 2019                            | 1380      |
# | 2020                            | 204       |
#
#
# ### by record last_update
#
# | **strftime('%Y', record.last_update)** | **count(\*)** |
# | -------------------------------------- | ------------- |
# |                                        | 76            |
# | 2012                                   | 1771694       |
# | 2013                                   | 28372         |
# | 2014                                   | 22300         |
# | 2015                                   | 19454         |
# | 2016                                   | 18589         |
# | 2017                                   | 14890         |
# | 2018                                   | 6740          |
# | 2019                                   | 3635          |
# | 2020                                   | 634           |
#
#
# ### by tag count (1886384 total records)
#
# ```
# 001 : 1577163
# 008 : 1886384
# 245 : 1886102
# 260 : 1885153
# 773 : 1886625
# 907 : 1886384
# 998 : 1886384
# 944 : 1780372
# 941 : 1780372
# 959 : 1577155
# 650 : 3873316
# 948 : 34446
# 100 : 7
# 600 : 9
# 540 : 15
# 250 : 5
# 658 : 1
# 775 : 28
# 007 : 2
# 733 : 3
# 700 : 1
# 730 : 5
# 490 : 1
# 770 : 3
# 655 : 1
# ```
#
# ### Common / Repeating Titles
#
# | **title**                                       | **count(\*)** |
# | ----------------------------------------------- | ------------- |
# | Obituaries                                      | 201945        |
# | Death Notice                                    | 186248        |
# | Obituary                                        | 18102         |
# | People On The Move (Column)                     | 5300          |
# | Field Of Honor                                  | 5154          |
# | Funeral Directory                               | 3973          |
# | Death Notices                                   | 3629          |
# | Deaths                                          | 3228          |
# | On The Field Of Honor                           | 2321          |
# | People On The Move                              | 2210          |
# | People                                          | 1971          |
# | In Loving Remembrance                           | 1840          |
# | Local Report                                    | 1490          |
# | Todays War Casualties                           | 1486          |
# | Card of Thanks                                  | 1423          |
# | In Memoriam                                     | 1402          |
# | Death                                           | 1308          |
# | Career Moves                                    | 1261          |
# | Business People                                 | 1249          |
# | In Memory                                       | 1151          |
# | Downtowners                                     | 1112          |
# | Making It: Promotions & New On The Job (Column) | 1089          |
# | Weddings                                        | 1055          |
# | Career Moves (Column)                           | 881           |
# | Celebrations (column)                           | 744           |
# | Congrats                                        | 682           |
# | Today's War Casualties                          | 667           |
# | War Casualties                                  | 662           |
# | Update                                          | 636           |
# | \*\*REQUIRED FIELD\*\*                          | 607           |
# | Business people                                 | 525           |
# | Honors                                          | 513           |
# | Heads Above The Crowd                           | 484           |
# | Today's Mover                                   | 435           |
# |                                                 | 372           |
# | On the move                                     | 365           |
# | In Loving Memory                                | 361           |
# | Career moves                                    | 358           |
# | Local Reports                                   | 353           |
# | Tristate's Most Wanted (Column)                 | 343           |
# | Honors (Column)                                 | 321           |
# | By the Numbers (column)                         | 321           |
# | Fallen On The Field Of Honor                    | 306           |
# | Investor Profile                                | 303           |
# | Hometown Hero                                   | 298           |
# | People: Promotions and hires                    | 292           |
# | Mr. Downtowner                                  | 288           |
# | Ms. Downtowner                                  | 285           |
# | People on the move                              | 271           |
# | Insider (Column)                                | 270           |
# | Kentucky Losses                                 | 266           |
# | Night Beat                                      | 252           |
# | People: Awards                                  | 233           |
# | Nonprofit File                                  | 232           |
# | Celebrations                                    | 231           |
# | On The Record (Column)                          | 225           |
# | Scene around town                               | 223           |
# | Mortality Report                                | 194           |
# | Young Leaders                                   | 177           |
# | Death Otice                                     | 176           |
# | Death Ontice                                    | 174           |
# | In Sad But Loving Remembrance                   | 171           |
# | Faces in the community                          | 169           |
# | Freed From Prison Camp                          | 159           |
# | Earnings                                        | 158           |
# | On The Record                                   | 157           |
# | People: Appointments                            | 155           |
# | Late Reported War Casualties                    | 152           |
# | With The Military                               | 147           |
# | Best Bets                                       | 144           |
# | Noteworthy News                                 | 130           |
# | Biography                                       | 121           |
# | Scene Around Town                               | 120           |
# | Men Behind The War Chest                        | 112           |
# | People: Honors and appointments                 | 111           |
# | Making It: Awards & Honors (Column)             | 108           |
# | Turning Back The Clock                          | 107           |
# | People (Column)                                 | 107           |
# | The Big Number                                  | 104           |
# | Editorial                                       | 104           |
# | Good Sports (column)                            | 102           |
# | Local Report Bicentennial Capsule               | 100           |
#
#
#
# ### By Publication Name
#
# | pub_name                             | count(\*) |
# | ------------------------------------ | --------- |
# | Cincinnati Enquirer                  | 952950    |
# | Post                                 | 529767    |
# | Cincinnati Times Star                | 156516    |
# | Cincinnati Post Times Star           | 75718     |
# | Cincinnati Business Courier          | 44307     |
# | Cincinnati Enquirer                  | 32790     |
# | Cincinnati Post                      | 28629     |
# | Cincinnati Herald                    | 21981     |
# | Downtowner                           | 10123     |
# | Commercial Tribune                   | 7092      |
# | Cincinnati Magazine                  | 6843      |
# | Business Record                      | 3748      |
# | Cincinnati Commercial                | 3163      |
# | Greater Cincinnati Business Record   | 2452      |
# | Cincinnati Gazette                   | 883       |
# | Cincinnati Commercial Tribune        | 791       |
# | Cincinnati Post                      | 778       |
# | Cincinnati Enqui0rer                 | 2         |
# | Cincinnati Daily Press               | 2         |
# | Cincinnati Commmercial Tribune       | 2         |
# | Cincinnati Commercial Gazette        | 2         |
# | Cincinnaati Enquirer                 | 2         |
# | Ci0ncinnati Enquirer                 | 2         |
# | CVincinnati Enquirer                 | 2         |
# | 0Cincinnati Enquirer                 | 2         |

# %% [markdown]
# ## Millennium Client
#
# ### Example Record
#
# Here's an example record as it looks in the client
#
# ![image.png](attachment:8feb57f2-023f-40cd-8734-4b8069bc3320.png)

# %% [markdown]
# ```
# 001 - "Bib Utility No."
# 245 - "Title"
# 260 - "Publication Info"
# 650 - "Subject"
# 773 - "Citation Info"
# 944 - Symphony Catkey"
# 941 - "Misc."
# 959 - "Misc."
# ```
#
# ```
# 907 subfield a - "bib record num"
# 907 subfield b - "Last Updated"
# 907 subfield c - "Created"
# ```
#
# ```
# 998 subfield a - "Location"
# 998 subfield b - "Cat. Date"
# 998 subfield c - "Bib Level"
# 998 subfield d - "Format (MatType)"
# 998 subfield e - ???
# 998 subfield f - "Language"
# 998 subfield h - "Skip"
# ```

# %% [markdown]
# example record (matches Millennium view above)
#
# ```json
# [
#     {
#         "001": "NEWS-122"
#     },
#     {
#         "008": "                                        "
#     },
#     {
#         "245": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "Pilot Killed At Lunken"
#                 }
#             ]
#         }
#     },
#     {
#         "260": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "c": "1989"
#                 }
#             ]
#         }
#     },
#     {
#         "650": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "Ott, Robert Jeffrey"
#                 }
#             ]
#         }
#     },
#     {
#         "650": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "Airplane Accidents"
#                 }
#             ]
#         }
#     },
#     {
#         "650": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "Lunken Airport"
#                 }
#             ]
#         }
#     },
#     {
#         "773": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "Cincinnati Enquirer"
#                 },
#                 {
#                     "g": "12/18/1989 A:1"
#                 }
#             ]
#         }
#     },
#     {
#         "907": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": ".b10030062"
#                 },
#                 {
#                     "b": "10-03-12"
#                 },
#                 {
#                     "c": "08-31-12"
#                 }
#             ]
#         }
#     },
#     {
#         "998": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "2ma"
#                 },
#                 {
#                     "b": "07-23-04"
#                 },
#                 {
#                     "c": "m"
#                 },
#                 {
#                     "d": "9"
#                 },
#                 {
#                     "e": "-"
#                 },
#                 {
#                     "f": "eng"
#                 },
#                 {
#                     "h": "0"
#                 }
#             ]
#         }
#     },
#     {
#         "944": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "4"
#                 }
#             ]
#         }
#     },
#     {
#         "941": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "20040723"
#                 },
#                 {
#                     "b": "0"
#                 },
#                 {
#                     "c": "BATCH"
#                 },
#                 {
#                     "d": "0"
#                 }
#             ]
#         }
#     },
#     {
#         "959": {
#             "ind1": " ",
#             "ind2": " ",
#             "subfields": [
#                 {
#                     "a": "Newspaper Article"
#                 },
#                 {
#                     "m": "MAIN"
#                 },
#                 {
#                     "t": "MICROFILM"
#                 },
#                 {
#                     "l": "MAGSTACKS"
#                 },
#                 {
#                     "x": "MICROFORM"
#                 },
#                 {
#                     "r": "N"
#                 },
#                 {
#                     "s": "Y"
#                 },
#                 {
#                     "p": "$0.00"
#                 }
#             ]
#         }
#     }
# ]
# ```
